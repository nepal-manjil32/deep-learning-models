# %% [markdown]
# **<font size='+3' color='green'>Convolutional Neural Network</font>**

# %% [markdown]
# ### Importing the libraries

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
print(tf.__version__)
# Out:
# 2.15.0

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Preprocessing the Training set

# %%
# Applying transformations on training set images to avoid overfitting

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

training_set = train_datagen.flow_from_directory('/Users/manjilnepal/Desktop/Machine Learning/ML Datasets/CNN Dataset/training_set',
                                                 target_size = (64, 64), # Size of image
                                                 batch_size = 32,
                                                 class_mode = 'binary')

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('/Users/manjilnepal/Desktop/Machine Learning/ML Datasets/CNN Dataset/test_set'',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initialising the CNN

# %%
cnn = tf.keras.models.Sequential() # sequence of layers

# %% [markdown]
# ### Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters = 32, kernel_size = 3, activation = 'relu', input_shape = [64, 64, 3]))

# filters -> number of feature detectors we want
# kernel_size -> no of rows/columns of feature detector
# input_shape -> [64, 64, 3] ; 3 for 3-D since we are working with b/w images and 64,64 is the target_size we set during tranformation

# %% [markdown]
# ### Step 2 - Pooling

# %%
# Adding a pooling layer to our convolutional layer

cnn.add(tf.keras.layers.MaxPool2D(pool_size = 2, strides = 2))

# pool_size -> no of rows/columns of used for max pooling in feature map
# strides -> how many pixels to move the frame when doing the max pooling
# padding -> used in the corner pixels during pooling

# %% [markdown]
# ### Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters = 32, kernel_size = 3, activation = 'relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size = 2, strides = 2))

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units = 128, activation = 'relu'))

# %% [markdown]
# ### Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# We just need one neuron in the output layer to classify cat or dogs

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
import numpy as np
from keras.preprocessing import image

test_image = image.load_img('/Users/manjilnepal/Desktop/Machine Learning/Deep Learning Models/Convulotional Neural Networks/CNN Dataset/single_prediction/cat_or_dog0.jpeg', target_size = (64, 64))
test_image = image.img_to_array(test_image) # Convert test_image into 2-D array
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
print(training_set.class_indices)
if(result[0][0] == 1):
  prediction = 'dog'
else:
  prediction = 'cat'

print(prediction)
